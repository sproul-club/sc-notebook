# %%
# Native imports
import sys
import os
import os.path
import json
from pprint import pprint
import urllib.request
import urllib.parse

# 3rd-party scraping/parsing imports
import grequests
import requests
from bs4 import BeautifulSoup
import dateutil.parser as dt

# 3rd-party data science imports
import pandas as pd
import seaborn as sns

# Used to make the plots bigger
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 8)

# %%
# Source: https://stackoverflow.com/a/312464
split_into_chunks = lambda lst, n: [lst[i:i + n] for i in range(0, len(lst), n)]

ORGS_CATALOG_URL = 'https://callink.berkeley.edu/api/discovery/search/organizations?orderBy%5B0%5D=UpperName%20asc&top=1600'
ORG_BASE_URL = 'https://callink.berkeley.edu/organization/'


def fetch_init_app_state(soup):
    for element in soup.find_all('script'):
        if len(element.contents) > 0 and 'window.initialAppState' in element.contents[0]:
            json_str = element.contents[0].split(' = ')[1][:-1]
            return json.loads(json_str)
    return None


def extract_email_from_org_html(org_html):
    soup = BeautifulSoup(org_html, 'html.parser')
    app_state = fetch_init_app_state(soup)

    email = app_state['preFetchedData']['organization'].get('email')
    return email


def scrape_emails():
    callink_data = json.loads(
        requests.get(ORGS_CATALOG_URL).text.strip()
    )
    
    num_orgs = callink_data['@odata.count']
    orgs = callink_data['value']

    callink_emails = []
    N = 20
    
    org_urls = [ORG_BASE_URL + org['WebsiteKey'] for org in orgs]
    org_url_chunks = split_into_chunks(org_urls, N)
    
    for i, orgs_chunk in enumerate(org_url_chunks):
        reqs = [grequests.get(org_url) for org_url in orgs_chunk]
        replies = grequests.map(reqs)
        emails = [extract_email_from_org_html(reply.text.strip()) for reply in replies]
        emails = [email for email in emails if email is not None]
        
        print('Emails processed:', (i + 1) * N)
        callink_emails += emails
    
    print('Number of organizations:', num_orgs)
    print('Number of valid emails collected:', len(callink_emails))
    return callink_emails

# %%
# %%time
scrape_emails()
# Out:
# Emails processed: 20
# Emails processed: 40
# Emails processed: 60
# Emails processed: 80
# Emails processed: 100
# Emails processed: 120
# Emails processed: 140
# Emails processed: 160
# Emails processed: 180
# Emails processed: 200
# Emails processed: 220
# Emails processed: 240
# Emails processed: 260
# Emails processed: 280
# Emails processed: 300
# Emails processed: 320
# Emails processed: 340
# Emails processed: 360
# Emails processed: 380
# Emails processed: 400
# Emails processed: 420
# Emails processed: 440
# Emails processed: 460
# Emails processed: 480
# Emails processed: 500
# Emails processed: 520
# Emails processed: 540
# Emails processed: 560
# Emails processed: 580
# Emails processed: 600
# Emails processed: 620
# Emails processed: 640
# Emails processed: 660
# Emails processed: 680
# Emails processed: 700
# Emails processed: 720
# Emails processed: 740
# Emails processed: 760
# Emails processed: 780
# Emails processed: 800
# Emails processed: 820
# Emails processed: 840
# Emails processed: 860
# Emails processed: 880
# Emails processed: 900
# Emails processed: 920
# Emails processed: 940
# Emails processed: 960
# Emails processed: 980
# Emails processed: 1000
# Emails processed: 1020
# Emails processed: 1040
# Emails processed: 1060
# Emails processed: 1080
# Emails processed: 1100
# Emails processed: 1120
# Emails processed: 1140
# Emails processed: 1160
# Emails processed: 1180
# Emails processed: 1200
# Emails processed: 1220
# Emails processed: 1240
# Emails processed: 1260
# Emails processed: 1280
# Emails processed: 1300
# Emails processed: 1320
# Emails processed: 1340
# Emails processed: 1360
# Emails processed: 1380
# Emails processed: 1400
# Emails processed: 1420
# Emails processed: 1440
# Emails processed: 1460
# Emails processed: 1480
# Number of organizations: 1462
# Number of valid emails collected: 1182
# CPU times: user 20.5 s, sys: 833 ms, total: 21.4 s
# Wall time: 1min 44s
# ['recruitment.berkeley@180dc.org',
#  '3dma.at.berkeley@gmail.com',
#  '3dmc.berkeley@gmail.com',
#  'fiveandtwo.berkeley@gmail.com',
#  'officers@abetterway.berkeley.edu',
#  'seanhkim@berkeley.edu',
#  'abbamodern@gmail.com',
#  'abcsketches@gmail.com',
#  'cal5@acacia.org',
#  'acecoaches@berkeley.edu',
#  'achievementim@gmail.com',
#  'info@acts2fellowship.org',
#  'calasae@gmail.com',
#  'calasapresident@gmail.com',
#  'aasdsocialmedia@gmail.com',
#  'afxdance@gmail.com',
#  'dalilalva@berkeley.edu',
#  'adseberkeley@gmail.com',
#  'axopichapterpresident@gmail.com',
#  'axs.sigma.president@gmail.com',
#  'info@aquadelt.org',
#  'caladpipresident@gmail.com',
#  'aakashr@berkeley.edu',
#  'ago_actives@lists.berkeley.edu',
#  'AKARHO1921@gmail.com',
#  'brandonqinqin@gmail.com',
#  'calalphaphipresident@gmail.com ',
#  'icecolddynasty@gmail.com',
#  'president@calaphio.com',
#  'calapx@gmail.com',
#  'ato.berkeley@gmail.com',
#  'berkeleyaltprotein@gmail.com',
#  'berkeleyaltbreaks@gmail.com',
#  'kvillacorta@berkeley.edu',
#  'blast@law.berkeley.edu',
#  'execs@calaaf.com',
#  'acsberkeley@gmail.com',
#  'berkeleylawacs@gmail.com',
#  'aiasberkeley@gmail.com',
#  'aiche.berkeley@gmail.com',
#  'info@alcsi.org',
#  'berkeleyamsa@gmail.com',
#  'amwaberkeley@gmail.com',
#  'president@ans.berkeley.edu',
#  'UCBTrustee@theaosa.org',
#  'berkeleyapsa@gmail.com',
#  'americanredcrossatcal@gmail.com',
#  'calasceofficers@gmail.com',
#  'berkeleystudentasla@gmail.com',
#  'asme.cal@gmail.com',
#  'americastoothfairyatberkeley@gmail.com',
#  'amigos.ucberkeley@gmail.com',
#  'ahcberkeley@gmail.com',
#  'katalina@berkeley.edu',
#  'executive@anova.berkeley.edu',
#  'auaucberkeley@gmail.com',
#  'berkeleyantitrafficking@gmail.com',
#  'dghandour@berkeley.edu',
#  'arcrepertory@gmail.com',
#  'chibuzorobiorah@berkeley.edu',
#  'ucbtango@gmail.com',
#  'jillychoi@berkely.edu',
#  'CalBerkeleyASA@gmail.com',
#  'estherykim@berkeley.edu',
#  'artandmind.berkeley@gmail.com',
#  'artistsinresonanceucb@gmail.com',
#  'aia.berkeleylaw@gmail.com',
#  'alix.vadot@berkeley.edu',
#  'vegansam@berkeley.edu',
#  'ascendberkeley.exec@gmail.com',
#  'berkeley@ashanet.org',
#  'ucbsph.apiwc@gmail.com',
#  'aapihrg.info@gmail.com',
#  'ucberkeleyaaa@gmail.com',
#  'linda.chen@berkeley.edu',
#  'aalj@berkeley.edu',
#  'berkeleyapalsa@gmail.com',
#  'ucb.apapla@gmail.com',
#  'sharon.jan@berkeley.edu',
#  'atpucberk@gmail.com',
#  'johnson_jessica@berkeley.edu',
#  'gfatima55@berkeley.edu',
#  'asrbatberkeley@gmail.com',
#  'team@ace.berkeley.edu',
#  'akaberkeley@gmail.com',
#  'aphidsco@gmail.com',
#  'exec@caltv.berkeley.edu',
#  'grants@asuc.org ',
#  'decalprogram@gmail.com',
#  'innovativedesignatcal@gmail.com',
#  'aavp@asuc.org',
#  'eavp@asuc.org',
#  'evp@asuc.org',
#  'president@asuc.org opchief@asuc.org',
#  'help (at) ocf.berkeley.edu',
#  'senate@asuc.org',
#  'legalclinic@asuc.org',
#  'adminoffice@asuc.org',
#  'grants@asuc.org',
#  'grants@asuc.org',
#  'disabledstudentscommittee@asuc.org',
#  'diversityaffairscommission@asuc.org',
#  'financialwellness@asuc.org',
#  'housing@asuc.org',
#  'legal@asuc.org',
#  'mentalhealthcommission@asuc.org',
#  'ayahya@asuc.org',
#  'aaguilar@asuc.org',
#  'aprakash@asuc.org',
#  'ctellem@asuc.org',
#  'espickermann@asuc.org',
#  'jcastro@asuc.org',
#  'mchen@asuc.org',
#  'mtorrico@asuc.org',
#  'msavides@asuc.org',
#  'ngarcia@asuc.org',
#  'rsoo@asuc.org',
#  'rzhang@asuc.org',
#  'rsholkoff@asuc.org',
#  'rshah@asuc.org',
#  'srodriguez@asuc.org',
#  'speng@asuc.org',
#  'sbancroft@asuc.org',
#  'sheenade@asuc.org',
#  'wliu@asuc.org',
#  'transferstudentrep@asuc.org',
#  'sexualviolence@asuc.org',
#  'help@berkeleysao.org',
#  'superb@berkeley.edu',
#  'sustainability@asuc.org',
#  'technology@asuc.org',
#  'eavpvotecoalition@asuc.org',
#  'atrium.berkeley@gmail.com',
#  'calaurumcosmetics@gmail.com',
#  'ucb.azaad@gmail.com',
#  'berkeleybside@gmail.com',
#  'rasareachan@berkeley.edu',
#  'ballet.berkeley@gmail.com',
#  'reflejosdemexico.cal@gmail.com',
#  'bsaatberkeley@gmail.com',
#  'leadership@berkeley.edu',
#  'barbellatberkeley@gmail.com',
#  'editor@baremagazine.org',
#  'managing@barestage.berkeley.edu',
#  'info@beacn.berkeley.edu',
#  'baoc.rep@gmail.com',
#  'jade_fostvedt@berkeley.edu',
#  'bavrd@berkeley.edu',
#  'bethematch.berkeley@gmail.com',
#  'bearballersociety@gmail.com',
#  'bearbuddies.berkeleylaw@gmail.com',
#  'calbearcloset@gmail.com',
#  'ryanwchen@berkeley.edu',
#  'calbearraid@gmail.com',
#  'bearettesatberkeley@gmail.com',
#  'bearsagainstice@protonmail.com',
#  'bearsforisrael@gmail.com',
#  'info@bearsforpalestine.org',
#  'bercatberkeleylaw@gmail.com',
#  'berc.undergraduate@gmail.com',
#  'berke1337-admin@lists.berkeley.edu',
#  'bampfasc@berkeley.edu',
#  'berkeleybahaiclub@gmail.com',
#  'bbs.ucb@gmail.com',
#  'bcsa.core@gmail.com',
#  'calbells@gmail.com',
#  'bcssa.official@gmail.com',
#  'hannahku@berkeley.edu',
#  'calcollegerepublicans@gmail.com',
#  'clarisahuang@berkeley.edu',
#  'BerkeleyDisasterTeam@berkeley.edu',
#  'editor@econreview.berkeley.edu',
#  'copresidents@berc.berkeley.edu',
#  'beeps@beeps.berkeley.edu',
#  'berkeleyfictionreview@gmail.com',
#  'info@forum.berkeley.edu',
#  'berkeleygraduate@ga.berkeley.edu',
#  'berkeleyimmigrationgroup@law.berkeley.edu',
#  'berkeleybisa@gmail.com',
#  'berkeley.innovation@gmail.com',
#  'bjalp@berkeley.edu',
#  'bjcl@berkeley.edu',
#  'bjell@berkeley.edu',
#  'bjesl@berkeley.edu',
#  'bglj@berkeley.edu',
#  'bjil@berkeley.edu',
#  'tiffanyhamidjaja@berkeley.edu',
#  'probonobloc@law.berkeley.edu',
#  'batpro@law.berkeley.edu ',
#  'berkeleylawmsa@gmail.com',
#  'berkeleylegals@gmail.com',
#  'pio@berkeleymrc.org',
#  'chief@bmun.org ',
#  'curtisrumrill@berkeley.edu',
#  'contact@boaa.berkeley.edu',
#  'bpreditors@gmail.com',
#  'bproutreach@gmail.com',
#  'executive@berkeleyproject.org',
#  'contact@bppj.berkeley.edu',
#  'sciencereview@gmail.com',
#  'bsj.berkeley@gmail.com',
#  'btlj@berkeley.edu',
#  'berkeleytennisassociation@gmail.com',
#  'buj@berkeley.edu',
#  'bwib.berkeley@gmail.com',
#  'maudetipton@berkeley.edu',
#  'berkeleybestbuddies@gmail.com',
#  'bestlaidplansimprov@gmail.com',
#  'rush.berkeleybap@gmail.com ',
#  'mervitan@berkeley.edu',
#  'info@beyondacademia.berkeley.edu',
#  'ucberkeley@bpshi.com',
#  'biasbusters-admin@lists.eecs.berkeley.edu',
#  'hello@bicycal.berkeley.edu',
#  'bigdata.berkeley@gmail.com',
#  'bbi@bbi.berkeley.edu',
#  'bioeBEAST@gmail.com',
#  'bioehs.exec@lists.berkeley.edu',
#  'bioethical.berkeley@gmail.com',
#  'biofuelstechnology@gmail.com',
#  'calbmes@gmail.com',
#  'admin@bioprinting.berkeley.edu',
#  'berkeley.bsgsa@gmail.com',
#  'baeh@berkeley.edu',
#  'berkeleymswblackcaucus@gmail.com',
#  'ucberkeleybessa@gmail.com',
#  'janehenderson@berkeley.edu',
#  'bgess@berkeley.edu',
#  'caleb_dawson@berkeley.edu',
#  'bplaberkeley@gmail.com',
#  'brrcboard@gmail.com',
#  'blacksociologicalalliance@gmail.com',
#  'chair.calbsu@gmail.com',
#  'calbsha@gmail.com',
#  'angelicapagan@berkeley.edu',
#  'admin@blockchain.berkeley.edu',
#  'info@blockeley.com',
#  'projectbloodpressure@gmail.com',
#  'info@yearbook.berkeley.edu',
#  'team@calblueprint.org',
#  'Ucberkeleygames@gmail.com',
#  'karnikhajjar@berkeley.edu',
#  'bonehealthinitiative@gmail.com',
#  'berkeleybootlegcomedy@gmail.com',
#  'boricuasinberkeley@gmail.com',
#  'rwoody@berkeley.edu',
#  'braintrustberkeley@gmail.com',
#  'natasha.blazer@berkeley.edu',
#  'brasaberkeley@gmail.com',
#  'executivebridges@gmail.com',
#  'bridgeusa.berkeley@gmail.com',
#  'brownissues.ucb@gmail.com',
#  'buildliteracy@berkeley.edu',
#  'bulletjournalbears@gmail.com',
#  'bab.berkeley@gmail.com',
#  'berkeleytechnologyinitiative@gmail.com',
#  'calbcec@gmail.com',
#  'businessreviewatberkeley@gmail.com',
#  'btnexecboard@btn.berkeley.edu',
#  'students@casa.berkeley.edu',
#  'calaclu1920@gmail.com',
#  'webmaster@calanimagealpha.com',
#  'california.archery@gmail.com',
#  'president@caldems.com',
#  'calbhangra@gmail.com',
#  'calboxingclub@gmail.com',
#  'intervarsityccf@gmail.com',
#  'californiaclubtennis@gmail.com',
#  'calcommunitymusic@gmail.com',
#  'caldragonboat@gmail.com',
#  'calequestrianclub@gmail.com',
#  'ucbfigureskating@gmail.com',
#  'calhabitat.pres@gmail.com',
#  'evickers29@berkeley.edu',
#  'calhawaiiclub@gmail.com',
#  'k.lyon@berkeley.edu',
#  'publicserviceinternships@berkeley.edu',
#  'calinthecapital@gmail.com',
#  'caljapanclub@gmail.com',
#  'clam.art.editor@gmail.com',
#  '18rway@berkeley.edu',
#  'safta@calperformances.org',
#  'calprevet.president@gmail.com',
#  'cal.q.and.a@gmail.com',
#  'info@calrotaract.org',
#  'calsailing@gmail.com',
#  'calseismicteam@gmail.com',
#  'staph@berkeley.edu',
#  'alexander.rodriguez@berkeley.edu',
#  'calsmv@gmail.com',
#  'calttc@gmail.com',
#  'caltaiko@gmail.com',
#  'president@caltriathlon.com',
#  'caluphc.publichealth@gmail.com',
#  'calvetsgroup@gmail.com',
#  'calclublacrosse@gmail.com',
#  'calwomens.waterpolo@gmail.com',
#  'calwomensrugby@gmail.com',
#  'calibermag@gmail.com',
#  'carc@berkeley.edu',
#  'cahpsa.berkeley@gmail.com',
#  'calmocktrial@gmail.com',
#  'calpirgbears@gmail.com',
#  'berkeleyscc@gmail.com',
#  'lead@berkeley.edu',
#  'calsol-me@berkeley.edu',
#  'berkeley@campkesem.org',
#  'mcharles@berkeley.edu',
#  'apasdoffice@gmail.com',
#  'asucstudentunion@berkeley.edu',
#  'basicneedscenter@berkeley.edu',
#  'artstudio@berkeley.edu',
#  'info.artsdesign@berkeley.edu',
#  'sashachang@berkeley.edu',
#  'studyabroad@berkeley.edu',
#  'https://ssall.zendesk.com/hc/en-us',
#  'dining@berkeley.edu',
#  'lupeg@berkeley.edu',
#  'disabilityculture@berkeley.edu',
#  'eventservices@berkeley.edu',
#  'lead@berkeley.edu',
#  'mcc.community@berkeley.edu',
#  'nasd@berkeley.edu',
#  'rhershkowitz@berkeley.edu',
#  'berkeleymoves@berkeley.edu',
#  'pathtocare@berkeley.edu',
#  'studentmedia@berkeley.edu',
#  'rhershkowitz@berkeley.edu',
#  'serc@berkeley.edu',
#  'slc@berkeley.edu',
#  'sof@berkeley.edu',
#  'techfund@berkeley.edu',
#  'tgif_info@berkeley.edu',
#  'e-ref@library.berkeley.edu',
#  'geneq@berkeley.edu',
#  'publicservice@berkeley.edu',
#  'cef.berkeley@gmail.com',
#  'derektzeng@berkeley.edu',
#  'ashwinbindra@berkeley.edu',
#  'cardsforcourageberkeley@gmail.com',
#  'casaesperanzaberkeley@gmail.com',
#  'casesovercoffeeatberkeley@gmail.com',
#  'taylor.chelan@berkeley.edu',
#  'smt.exec@calnewman.org',
#  'catholicsatberkeleylaw@gmail.com',
#  'eugenewlau@berkeley.edu',
#  'wearecelli@gmail.com',
#  'CAFEatucb@gmail.com',
#  'jenliu2@berkeley.edu',
#  'chec.berkeley@gmail.com',
#  'gsac@lists.berkeley.edu',
#  'berkeley.chemecar@gmail.com',
#  'ucbglc@gmail.com',
#  'curieatberkeley@gmail.com',
#  'ucbchess@gmail.com',
#  'berkeleyxe@gmail.com',
#  'calchiomegapresident@gmail.com',
#  'andreasmaass@berkeley.edu',
#  'checochair2@gmail.com',
#  'casistas@gmail.com',
#  'berkeleychineseacappella@gmail.com',
#  'chinesefinanceclub@gmail.com',
#  'berkeleycgpsa@gmail.com',
#  'chinesepeopleunion@gmail.com',
#  'syz0516@berkeley.edu',
#  'hi@7pmsalon.org',
#  'csaberkeley@gmail.com',
#  'ashleyhuang@berkeley.edu',
#  'chyk-berkeley-active@googlegroups.com',
#  'berkeleycmda@gmail.com',
#  'christiansatberkeleylaw@berkeley.edu',
#  'ucb.coc@gmail.com',
#  'chunjinahm@gmail.com',
#  'info.cinebears@gmail.com',
#  'capclubberkeley@gmail.com',
#  'cki.sarahg@gmail.com',
#  'faizkhwaja@berkeley.edu',
#  'stubbsjessica@berkeley.edu',
#  'lucia@berkeley.edu',
#  'ceejfc@berkeley.edu',
#  'js98@berkeley.edu',
#  'classicalforumberkeley@gmail.com',
#  'ucbclear@gmail.com',
#  'calclimbingofficers@googlegroups.com',
#  'cliosscroll@gmail.com',
#  'cloudatcal@gmail.com',
#  'berkeleycmg@gmail.com',
#  'curtisrumrill@berkeley.edu',
#  'coalitionfordiversity@gmail.com',
#  'cifmpatcal@gmail.com',
#  'ccmpatberkeley@gmail.com',
#  'joellefe@berkeley.edu',
#  'california@bamn.com',
#  'contact@codebase.berkeley.edu',
#  'info@codeology.club',
#  'cssa.berkeley@gmail.com',
#  'd1abears@collegediabetesnetwork.org',
#  'team@collegeleap.cc',
#  'carpbayarea@gmail.com',
#  'juan@berkeley.edu',
#  'colorsoftheater@gmail.com',
#  'info@combatrobotics.berkeley.edu',
#  'comicsstudiodecal@gmail.com',
#  'baycommunitywellness@gmail.com',
#  'trw@berkeley.edu',
#  'crj@berkeley.edu',
#  'berkeleycluj@gmail.com',
#  'mentors@berkeley.edu',
#  'pb@csua.berkeley.edu',
#  'calconcretecanoe@gmail.com',
#  'confiatcal@gmail.com',
#  'hello@connected.berkeley.edu',
#  'ucbconstructionteam@gmail.com',
#  'berkeley@consultyourcommunity.org',
#  ' con@berkeley.edu',
#  'caps@law.berkeley.edu',
#  'c3po@law.berkeley.edu',
#  'maddypilgrim@berkeley.edu',
#  'angelicavohland@berkeley.edu',
#  'calorigami@gmail.com',
#  'amyzh@berkeley.edu',
#  'calcreate@gmail.com',
#  'cal.ccas@gmail.com',
#  'xroadscf@gmail.com',
#  'crsso@lists.berkeley.edu',
#  'berkeleycru@gmail.com',
#  'cskickstart@gmail.com',
#  'ucbears4cubs@gmail.com',
#  'berkeleycubanamericans@gmail.com',
#  'editor@dailycal.org',
#  'berkeleydancecommunity@gmail.com',
#  'dancethebay@gmail.com',
#  'dwxpresidents@gmail.com',
#  'daraja.berkeley@gmail.com',
#  'info@dss.berkeley.edu',
#  'datagood@berkeley.edu',
#  'datastory.president@gmail.com',
#  'datongsociety@gmail.com',
#  'decoloresucb@gmail.com',
#  'contact@debate.berkeley.edu',
#  'decadence.berkeley@gmail.com',
#  'decode.build@gmail.com',
#  'adithi@berkeley.edu',
#  'darby.aono@berkeley.edu',
#  'deltaconsulting.berkeley@gmail.com',
#  'caltrideltapresident@gmail.com',
#  'caldelta.epsilon.mu@gmail.com',
#  'dggammapresident@gmail.com',
#  'president@berkeley.dka.org',
#  'berkeleydpe@gmail.com',
#  'kappa1921@gmail.com',
#  'ucbdeltaxiphi@gmail.com',
#  'caldibs@gmail.com',
#  'ajsolovy@berkeley.edu',
#  'designatberk@gmail.com',
#  'cloudcomputingdecal@gmail.com',
#  'digitalrightsproject@law.berkeley.edu',
#  'ucberkeleydilse@gmail.com',
#  'drp@berkeley.edu',
#  'disneyclubatberkeley@gmail.com',
#  'diversatech.berkeley@gmail.com',
#  'msf.ucberkeley@gmail.com',
#  'downsyndromeberkeley@gmail.com',
#  'cal.drawntoscale@gmail.com',
#  'Berkeley.Dream@gmail.com',
#  'eeri@berkeley.edu',
#  'chair@eau.berkeley.edu',
#  'minsookim729@berkeley.edu',
#  'dreamersclinic@berkeley.edu',
#  'jsycoff@berkeley.edu',
#  'ecodeatberkeley@gmail.com',
#  'julia.whitehead@berkeley.edu',
#  'ursan@berkeley.edu',
#  'epic.berkeley@gmail.com',
#  'edreimaginedberkeley@gmail.com',
#  'admin@eaberkeley.com',
#  'eggsteroverall@gmail.com',
#  'ucberkeley.ego@gmail.com',
#  'molly_haley@berkeley.edu',
#  'eleven.ucb@gmail.com',
#  'enabletechberkeley@gmail.com',
#  'president@esc.berkeley.edu',
#  'engineeringwellnessatberkeley@gmail.com',
#  'beam.teach@gmail.com',
#  'officers@esw.berkeley.edu',
#  'ewb.ucb@gmail.com',
#  'berkeley.eua@gmail.com',
#  'cal.entomology@gmail.com',
#  'eso@lists.berkeley.edu',
#  'admin@entrepreneurs.berkeley.edu',
#  'ecoslp@berkeley.edu',
#  'gostout@berkeley.edu',
#  'environment@law.berkeley.edu',
#  'berkeley.essa@gmail.com',
#  'calenviroteam@gmail.com',
#  'epsilonetaberkeley@gmail.com',
#  'jcaminiti@berkeley.edu',
#  'equitybeyondbarriers@gmail.com',
#  'ergo@lists.berkeley.edu',
#  'espmgdc@berkeley.edu',
#  'espmgsa@gmail.com',
#  'r.madden@berkeley.edu',
#  'hkn@hkn.eecs.berkeley.edu',
#  'etaomegachi@gmail.com',
#  'ethicalapparel@gmail.com',
#  'expdancecrew@gmail.com',
#  'eyh_ucb@googlegroups.com',
#  'exposureos.ucb@gmail.com',
#  'ronitnath@berkeley.edu',
#  'contact@xr.berkeley.edu',
#  'haominm98@berkeley.edu',
#  'calfastinternal@gmail.com',
#  'berkeleyclubsoftball@gmail.com',
#  'berkeleyfederalistsociety@gmail.com',
#  'feelgoodberkeley@gmail.com',
#  'dance.chinese@gmail.com',
#  'kirstychoi@berkeley.edu',
#  'FMLAofBerkeley@gmail.com',
#  'femtechberkeley@gmail.com',
#  'a.mendoza@berkeley.edu',
#  'ucberkeleyflsa@berkeley.edu',
#  'fesa@mfe.berkeley.edu',
#  'flejcon@gmail.com',
#  'fintechberkeley@gmail.com',
#  'berkeleylawfgp@gmail.com',
#  'yakira.mirabito@berkeley.edu',
#  'noaht@berkeley.edu',
#  'foodatberkeley@gmail.com',
#  'brandonqinqin@gmail.com',
#  'foodjustice@law.berkeley.edu',
#  'fstatcal@gmail.com',
#  'feedberkeley@gmail.com',
#  'FCSBerkeley@gmail.com',
#  'foresight.president@gmail.com',
#  'contact@ev.berkeley.edu',
#  'fsae@me.berkeley.edu',
#  'fostered@law.berkeley.edu',
#  'fimrc.berkeley@gmail.com',
#  'spauker@berkeley.edu',
#  'adhiv@freeventures.org',
#  'president@bsc.coop',
#  'execs@pbl.berkeley.edu',
#  'tiffani.johnson@berkeley.edu',
#  'bblj@law.berkeley.edu',
#  'cavp@ga.berkeley.edu',
#  'funding@ga.berkeley.edu',
#  'businessoffice@ga.berkeley.edu',
#  'president@ga.berkeley.edu',
#  'rules@ga.berkeley.edu',
#  'contact@gamedev.berkeley.edu',
#  'cal.gammaphi.pres@gmail.com',
#  'lambda@gammarholambda.org',
#  'calgammas@gmail.com',
#  'berkeleygarb@gmail.com',
#  'generationflowatberkeley@gmail.com',
#  'ucberkeleygensex@gmail.com',
#  'genupcoberkeley@gmail.com',
#  'geoengineering@berkeley.edu',
#  'jlamb2021@berkeley.edu',
#  'geowallcal@gmail.com',
#  'giamag.ucb@gmail.com',
#  'giantfilmmakers@gmail.com',
#  'golberkeley@gmail.com',
#  'giftsatberkeley@gmail.com',
#  'amritarama@berkeley.edu',
#  'ucberkeley@girlsteachinggirlstocode.org',
#  'gwcberkeley@gmail.com',
#  'berkeleygbb@gmail.com',
#  'gmbberkeley@gmail.com',
#  'globerkeley.president@gmail.com',
#  'berkeleygmma@gmail.com',
#  'gmtucberkeley@gmail.com',
#  'berkeley@grcglobalgroup.com',
#  'berkeley@globemed.org',
#  'elliot.choi@berkeley.edu',
#  'goldenwomenatberkeley@gmail.com',
#  'ced.gradstudentunion@berkeley.edu',
#  'gasp@berkeley.edu',
#  'gradsrza@gmail.com',
#  'gea@econ.berkeley.edu',
#  'samstein@berkeley.edu',
#  'educationresearchday@gmail.com',
#  'bre_editor@berkeley.edu',
#  'sjohns@berkeley.edu',
#  'gradswe@berkeley.edu',
#  'gasa@calgreeks.com',
#  'calgreenerhearts@gmail.com',
#  'greeningthegreeks@berkeley.edu',
#  'grotech.berkeley@gmail.com',
#  'groundupjournal@gmail.com',
#  'gvpp@berkeley.edu',
#  'hbsageneral@gmail.com',
#  'ucbhubba@gmail.com',
#  'team@calhacks.io',
#  'handsandfeetberkeley@gmail.com',
#  'happyperiodberkeley@gmail.com',
#  'hmap@berkeley.edu',
#  'admin@healsca.berkeley.edu',
#  'hbls@law.berkeley.edu',
#  'healthcarebusinessberkeley@gmail.com',
#  'fionalzx@berkeley.edu',
#  'heartfulness.berkeley20@gmail.com',
#  'contact@thehelixgroup.org',
#  'hepbproject@gmail.com',
#  'hc.ucberkeley@hercampus.com',
#  'ucbhau.cochairs@gmail.com',
#  'huchochairs@berkeley.edu',
#  'heuristicsquelch@gmail.com',
#  'arsine.03@berkeley.edu',
#  'studentboardpres@berkeleyhillel.org',
#  'hesberkeley8@gmail.com',
#  'steelonsteelhfc@gmail.com',
#  'hga@berkeley.edu',
#  'hsaberkeley@gmail.com',
#  'hosfellowship@gmail.com',
#  'hkaaberk@gmail.com',
#  'berkeleyhksa@gmail.com',
#  'Hear@berkeley.edu',
#  'hpv-me@berkeley.edu',
#  'anyal23@berkeley.edu',
#  'berkeleyanidealism@gmail.com',
#  'ieee@berkeley.edu',
#  'directors@igem.berkeley.edu',
#  't4cimprov@gmail.com',
#  'inbetweenberkeley@gmail.com',
#  'contact@isa.berkeley.edu',
#  'natives@berkeley.edu',
#  'imsa@ischool.berkeley.edu',
#  'ilr.ucb@gmail.com',
#  'jmiller558@berkeley.edu',
#  'iise@berkeley.edu',
#  'ucberkeleyite@gmail.com',
#  'jaeminlee0622@berkeley.edu',
#  'ifjberkeley@gmail.com',
#  'intermissionberkeley@gmail.com',
#  'ruijis@berkeley.edu',
#  'berkeleyintconsulting@gmail.com',
#  'delangs2020@gmail.com',
#  'berkeleyigsm@gmail.com',
#  'ihcaberkeley@gmail.com',
#  'ihrwslp@berkeley.edu',
#  'irap@law.berkeley.edu',
#  'ircofberkeley@gmail.com',
#  'international@calrotaract.org',
#  'crystal.gong@berkeley.edu',
#  'yehongtan@berkeley.edu',
#  'isab.officer@gmail.com',
#  'berkiusm@gmail.com',
#  'iysse.ucberkeley@gmail.com',
#  'natives@berkeley.edu',
#  'intervarsityccf@gmail.com',
#  'eduhmc@berkeley.edu',
#  'inventioncorps@icb.berkeley.edu',
#  'info@isaa.berkeley.edu',
#  'iscoucb@gmail.com',
#  'irish.dancers.berkeley@gmail.com',
#  'ucb.imsu@gmail.com',
#  'shshah2018@berkeley.edu',
#  'jdhillon813@berkeley.edu',
#  'nsimha@berkeley.edu',
#  'jerichocomedy@gmail.com',
#  'jsabl@law.berkeley.edu',
#  'jqasatberkeley@gmail.com',
#  'm_chen@berkeley.edu',
#  'kairosdanceco@gmail.com',
#  'kapiucb.president@gmail.com',
#  'omegathetaceo@gmail.com',
#  'ucbkgdpresident@gmail.com',
#  'kkgucbpresident@gmail.com',
#  'kendoclub.berkeley@gmail.com',
#  'berkeleykdsap@gmail.com',
#  'ucbkin@gmail.com',
#  'alaynakwan@berkeley.edu',
#  'kinkclubberkeley@gmail.com',
#  'lilyli@berkeley.edu',
#  'kevmo@berkeley.edu',
#  'kojobsatberkeley@gmail.com',
#  'calkasa@gmail.com',
#  'berkeleychurch0691@gmail.com',
#  'kpg.cal@gmail.com',
#  'kseaatcal@gmail.com',
#  'kosmosucb@gmail.com',
#  'hojung1019@berkeley.edu',
#  'lrlj@berkeley.edu',
#  'laalianza@berkeley.edu',
#  'LaRazaSLP@berkeley.edu',
#  'ahs.laborcoach@gmail.com',
#  'lta.do.president@gmail.com',
#  'LambdaThetaNu.Berkeley@gmail.com',
#  'ucblambdas@gmail.com',
#  'a.mendoza@berkeley.edu',
#  'llsatberkeley@gmail.com',
#  'lagses-contact@gmail.com',
#  'ucblbsa.president@gmail.com',
#  'lplsexecutivedirector@gmail.com',
#  'latinxstudentassociation.ucb@gmail.com',
#  'team@callaunchpad.org',
#  'lavenderallianceberkeley@gmail.com',
#  'berkeley.lpesoc@gmail.com',
#  'zsalazar2019@berkeley.edu',
#  'lsij.berkeleylaw@gmail.com',
#  'berkeleylsjp@gmail.com',
#  'lsad@law.berkeley.edu',
#  'layaofberkeley@gmail.com',
#  'jtennant@berkeley.edu',
#  'clairecombredet@berkeley.edu',
#  'lfsucberkeley@gmail.com',
#  'daniellaivanir@berkeley.edu',
#  'LSAatBerkeley@gmail.com',
#  'legalautomation@berkeley.edu',
#  'berkeleyleagueoflegends@gmail.com',
#  'letsrisementorship@gmail.com',
#  'linkbayarea@gmail.com',
#  'lindyonthesproul@gmail.com',
#  'callinguaphiles@gmail.com',
#  'megnar13@berkeley.edu',
#  'livepoetsatberkeley@gmail.com',
#  'local@calrotaract.org',
#  'Buckingbears@gmail.com',
#  'luxintlconsulting@gmail.com',
#  'passionlivingwater@gmail.com',
#  'lwpresence@googlegroups.com',
#  'contact@ml.berkeley.edu',
#  'maganda.eic@gmail.com',
#  'mainstacksdance@gmail.com',
#  'sravyab@berkeley.edu',
#  'marchofdimesberkeley@gmail.com',
#  'ucbmariachi@gmail.com',
#  'infoMDG2020@mdgberkeley.com',
#  'general@msea.berkeley.edu ',
#  'arutt@berkeley.edu',
#  'questions@bmt.berkeley.edu ',
#  'mgsa@math.berkeley.edu',
#  'musa@math.berkeley.edu',
#  'info@matriculate.org',
#  'mayaatcal@gmail.com',
#  'treyriddle@berkeley.edu',
#  'jmpsuitcase@gmail.com',
#  'contact@mri.berkeley.edu',
#  'armen.n.demirjian@berkeley.edu',
#  'ucbmedlife@gmail.com',
#  'candy0712n@berkeley.edu',
#  'cbarber@berkeley.edu',
#  'calmicrobes@gmail.com',
#  'berkeleymicrofinance@gmail.com',
#  'berkeleylawmelsa@gmail.com',
#  'mrayes@berkeley.edu',
#  'ucberkeleymenarrc@gmail.com',
#  'yebrat@gmail.com',
#  'mvbl@berkeley.edu',
#  'ucbmbn@gmail.com',
#  'mindfulnessatberkeley@gmail.com',
#  'mixedatberkeley@gmail.com',
#  'contact@mdb.dev',
#  'mcbcdna@gmail.com',
#  'mcbusa@gmail.com',
#  'mcbgso@gmail.com',
#  'moodpsych@gmail.com',
#  'admin@morningsignout.berkeley.edu',
#  'movefellowshipcal@gmail.com',
#  'ucb.movement@gmail.com',
#  'julia_forte@berkeley.edu',
#  'mcgc.president@calgreeks.com',
#  'tmcberkeley@gmail.com',
#  'board@msa.berkeley.edu',
#  'ucbnaacp@gmail.com',
#  'nalaproject@berkeley.edu',
#  'CompassionInActionUCBerkeley@gmail.com',
#  'ngcwberkeley@gmail.com',
#  'namiucb@gmail.com',
#  'nabj.cal@gmail.com',
#  'ucbncnw@gmail.com',
#  'JOSHUA.ALPERT@BERKELEY.EDU',
#  'nlgberkeleylaw@gmail.com',
#  'nosa.berkeley@gmail.com',
#  'nomas.berkeley@gmail.com',
#  'calnphc9@gmail.com',
#  'nslsucberkeley@gmail.com',
#  'nsslhaatberkeley@gmail.com',
#  'nalsa.ucberkeley@gmail.com',
#  'natyaberkeley@gmail.com',
#  'nrotc.ucberkeley@gmail.com',
#  'calkathak@gmail.com',
#  'sbohara@berkeley.edu',
#  'net-impact@berkeley.edu',
#  'contact@neurotech.berkeley.edu',
#  'newvoters.berkeley@gmail.com',
#  'ngcberkeley@gmail.com',
#  'nsa.ucb@gmail.com',
#  'nikkeichoralensemble@gmail.com',
#  'berkeleynsu@gmail.com',
#  'nring@math.berkeley.edu',
#  'seraph_fox3003@berkeley.edu',
#  'austin_mullen@berkeley.edu',
#  'nicu@nicu.berkeley.edu',
#  'nutrigenomxberkeley@gmail.com',
#  'oases@ebayc.org',
#  'caloceansociety@gmail.com',
#  'berkeley.owls@gmail.com',
#  'betamu@omegaphibeta.org',
#  'epsilonmuques1911@gmail.com',
#  'support@itot.berkeley.edu',
#  'lucyzhxy@berkeley.edu',
#  'onehealthsiatcal@gmail.com',
#  'ucb.onetrackinternational@gmail.com',
#  'mchristianson@math.berkeley.edu',
#  'odm.berkeley@gmail.com',
#  'operationsmileberkeley@gmail.com',
#  'info@otd.berkeley.edu',
#  'optimirconsulting@gmail.com',
#  'ucbso.obm@gmail.com',
#  'ucosa.president@gmail.com',
#  'ucosa.2021classpres@gmail.com',
#  'ucosa.2022ClassPres@gmail.com',
#  'ucosa.2023classpres@gmail.com',
#  'sfk@berkeley.edu',
#  'ostemberkeley@gmail.com',
#  'outlet.berkeley@gmail.com',
#  'mpacifico@berkeley.edu',
#  'ucbpacbears@gmail.com',
#  'berkeleypsa@gmail.com',
#  'paleoberkeley@gmail.com',
#  'pala@berkeley.edu',
#  'palestinianpublichealth@gmail.com',
#  'ucb.panel2people@gmail.com',
#  'phc.hrc@calgreeks.com',
#  'papercrane.berkeley@gmail.com',
#  'ucb.paragon.consulting@gmail.com',
#  'calparli@gmail.com',
#  'pih.engage.ucberkeley@gmail.com',
#  'ucberkeleyp4@gmail.com',
#  'patent.berkeley@gmail.com',
#  'snehakarthik@berkeley.edu',
#  'pmh.berkeley@gmail.com',
#  'berkeley@peerhealthexchange.org',
#  'peerwellnesscoalition@gmail.com',
#  'peaceatberkeley@gmail.com',
#  'penciltopaperucb@gmail.com',
#  'ptps.berkeley@gmail.com',
#  'calperennial@gmail.com',
#  'period.berkeley@gmail.com',
#  'info@perspective.berkeley.edu',
#  'phalanxpremed@gmail.com',
#  'phdconsultingclub@gmail.com',
#  'president.berkeleypad@gmail.com',
#  'phat.berkeley@gmail.com',
#  'berkeleyphichi@gmail.com',
#  'berkeleyphide@gmail.com',
#  'calphipsi@gmail.com',
#  'calphikapp@gmail.com',
#  'colinsnyder3@berkeley.edu',
#  'calphirho@gmail.com',
#  'calphilforum@gmail.com',
#  'emily.gu@berkeley.edu',
#  'phoenixsymphonyab@gmail.com',
#  'cabeta@pibetaphi.org',
#  'pikappcal@gmail.com',
#  'rexcalpilam@gmail.com',
#  'berkeleypse.president@gmail.com',
#  'spauker@berkeley.edu',
#  'paa.chair@gmail.com',
#  'pals@berkeley.edu',
#  'pahc.exec@gmail.com',
#  'ucbpba.exec@gmail.com',
#  'passexecutive@gmail.com',
#  'general@pasae.berkeley.edu',
#  'pinnacleconsultingberkeley@gmail.com',
#  'leadership@pioneers.berkeley.edu',
#  'pivotconsulting.berkeley@gmail.com',
#  'o.ortiz@berkeley.edu',
#  'info@plextech.berkeley.edu',
#  'pointe.berkeley@gmail.com',
#  'pokemonclubcal@gmail.com',
#  'ktwimsatt@berkeley.edu',
#  'policyreviewberkeley@gmail.com',
#  'noah.cole@berkeley.edu',
#  'info@polishclub.berkeley.edu',
#  'molly_haley@berkeley.edu',
#  'pcs.berkeley@gmail.com',
#  'p-cap@berkeley.edu',
#  'powerofaprincessberkeley@gmail.com',
#  'calphsc@gmail.com',
#  'calprelawreview@gmail.com',
#  'pltc.cal@gmail.com',
#  'ucberkeleypmhs@gmail.com',
#  'pills.prepharmacy@gmail.com',
#  'calpredentalsociety@gmail.com',
#  'prisoneradvocacy@berkeley.edu',
#  'info@privlab.berkeley.edu',
#  'boaltacappella@gmail.com',
#  'cal@productspace.org',
#  'ucberkeley@projectrishi.org',
#  'psmileinfo@gmail.com',
#  'leadership@prytanean.berkeley.edu',
#  'psichi@berkeley.edu',
#  'ucbpsychedelics@gmail.com',
#  'berkeleypsychologygroup@gmail.com',
#  'editorialboard@pha.berkeley.edu',
#  'tpilp@law.berkeley.edu',
#  'puenteatberkeley@gmail.com',
#  'pablopare@berkeley.edu',
#  'punjabatberkeley@gmail.com',
#  'debayanband@berkeley.edu',
#  'berkeleyqappa@gmail.com',
#  'board@ucbqarc.org',
#  'samstein@berkeley.edu',
#  'isamfitz@berkeley.edu',
#  'caucus@law.berkeley.edu',
#  'qsuberkeley@gmail.com',
#  'berkeleyquirs@gmail.com',
#  'londi@berkeley.edu',
#  'captains.calquidditch@gmail.com',
#  'rkeyal@berkeley.edu',
#  'raon.staff@gmail.com',
#  'ucb.raasramzat@gmail.com',
#  'rawmedianow@gmail.com',
#  'executive@raices.berkeley.edu',
#  'rserota@berkeley.edu',
#  'core@reach.berkeley.edu',
#  'redefineherstreetberkeley@gmail.com',
#  'gracekelly@berkeley.edu',
#  'reentryadvocacy@berkeley.edu',
#  'Chase.daws@ruf.org',
#  'berkeleyrcsa@gmail.com',
#  'reinnervate@gmail.com',
#  'asucrlastaff@gmail.com',
#  'brookedb@berkeley.edu',
#  'rha@berkeley.edu',
#  'communityrj@gmail.com',
#  'rjl.berkeley@gmail.com',
#  'ucberkeleyreuse@gmail.com',
#  'rightsstuff.ucb@gmail.com',
#  'pjbovee@berkeley.edu',
#  'berkeleyrhetoricsociety@gmail.com',
#  'riseatberkeley@gmail.com',
#  'calrobobears@gmail.com',
#  'robomasteratberkeley@gmail.com',
#  'leadership@rab.berkeley.edu',
#  'juanfesteva@berkeley.edu',
#  'roomonethousand@gmail.com',
#  'berkeleycubeclub@gmail.com',
#  'russian.berkeley@gmail.com',
#  'berkeley.sacnas@gmail.com',
#  'president@sagementorship.org',
#  'ucb.sahaara@gmail.com',
#  'berkeleyfinanceclub@gmail.com',
#  'salsaatcal@gmail.com',
#  'berkeley.saab@gmail.com',
#  'uc-berkeley@scholarsoffinance.org',
#  'spsa.info@gmail.com',
#  'scifiandfantasywritersworkshop@gmail.com',
#  'stefanofaubel@berkeley.edu',
#  'berkeley.SLAM@gmail.com',
#  'goldengatescioly@gmail.com',
#  'calscipol@gmail.com',
#  'spucb.studentboard@gmail.com',
#  'scubaberkeley@gmail.com',
#  'surg.berkeley@gmail.com',
#  'calseaonc@gmail.com',
#  'seealsoliteraryjournal@gmail.com',
#  'vincentooi@berkeley.edu',
#  'seedbaseconsulting@gmail.com',
#  'info@saecalbeta.org',
#  'calsam.prior@gmail.com',
#  'sigmaalphanu.cal@gmail.com',
#  'info@sigmaepsilonomega.com',
#  'ucbsep@gmail.com',
#  'betapsichapter1958@gmail.com',
#  'lambdaskpresident@gmail.com',
#  'ucbsmdpresident@gmail.com',
#  'ckeesey@berkeley.edu',
#  'alphasopipresident@gmail.com',
#  'alphachapter.president1996@gmail.com',
#  'syz.aicharter@gmail.com',
#  'ucbssa@gmail.com',
#  'contactus@ssa.berkeley.edu',
#  'sketchicho.ucb@gmail.com',
#  'calskiandsnowboardteam@gmail.com',
#  'club@skyhappiness.berkeley.edu',
#  'ronaldo.zhang@berkeley.edu',
#  'smartass@caldems.com',
#  'summerbui@berkeley.edu',
#  'jacob.ross@berkeley.edu',
#  'socialjusticezinecollective@gmail.com',
#  'socialwelfareberkeley@gmail.com',
#  'swagg.berkeley@gmail.com',
#  'socialwelfaregrads@gmail.com',
#  'consbio@lists.berkeley.edu',
#  'berkeleyses@gmail.com',
#  'calslugs@gmail.com',
#  'admin@sps.berkeley.edu',
#  'swe.berkeley@gmail.com',
#  'serc@berkeley.edu',
#  'vbartoszewi@berkeley.edu',
#  'songwriting.at.berkeley@gmail.com',
#  'salsa@law.berkeley.edu',
#  'ananyay99@berkeley.edu',
#  'ucb.seam@gmail.com',
#  'UCB.SASC@gmail.com',
#  'info@seb.berkeley.edu',
#  ...]
