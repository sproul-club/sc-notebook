# %%
# Native imports
import os
import json

# Import .env into loaded environment variables
from dotenv import load_dotenv
load_dotenv('../sc-backend/.env.dev')

# MongoDB Python driver import
import pymongo

# 3rd-party data science imports
import pandas as pd
import seaborn as sns
pd.set_option('display.max_rows', None)

OUTPUT_ORG_INFO_FILE = 'org-info.json'

# %% [markdown]
# # Step 0: Load the data

# %%
with open(OUTPUT_ORG_INFO_FILE, 'r') as fp:
    club_info_json = json.load(fp)
club_json_df = pd.DataFrame(club_info_json)
club_json_df = club_json_df[['name', 'email']]
club_json_df['name'].apply(lambda s: s if pd.isna(s) else s.strip())
club_json_df['email'].apply(lambda s: s if pd.isna(s) else s.lower().strip())
club_json_df.head()
# Out:
#                                     name                          email
# 0     180 Degrees Consulting at Berkeley             berkeley@180dc.org
# 1  3D Modeling and Animation at Berkeley     3dma.at.berkeley@gmail.com
# 2                  5&2 Community Service  fiveandtwo.berkeley@gmail.com
# 3               A Better Way at Berkeley        victorjann@berkeley.edu
# 4                                    ABA  tiffany.s.y.chen@berkeley.edu

# %%
club_json_df_copy = club_json_df.copy()
club_json_df_copy = club_json_df_copy[~pd.isna(club_json_df_copy['email'])]
club_json_df_copy.to_csv('callink-club-info.csv')
print(len(club_json_df_copy))
# Out:
# 1024

# %%
conn_string = os.getenv('MONGO_URI')
client = pymongo.MongoClient(conn_string)

# %%
club_info_db = []
for club in client['develop-db']['future_user'].find():
    club_info_db += [{'name': club['org_name'].strip(), 'email': club['org_email'].lower().strip()}]
club_db_df = pd.DataFrame(club_info_db)
club_db_df.head()
# Out:
#                                    name                         email
# 0                       Phi Alpha Theta       phat.berkeley@gmail.com
# 1  Berkeley Engineers and Mentors--BEAM          beam.teach@gmail.com
# 2              Phoenix Consulting Group           nian_s@berkeley.edu
# 3          Product Space at UC Berkeley          cal@productspace.org
# 4     The Berkeley Alt. Protein Project  berkeleyaltprotein@gmail.com

# %%
existing_clubs_df = pd.merge(club_json_df, club_db_df, how='inner', on='email')
existing_clubs_df.head()
# Out:
#                   name_x                          email              name_y
# 0  5&2 Community Service  fiveandtwo.berkeley@gmail.com        5&2 Berkeley
# 1            Abba Modern           abbamodern@gmail.com         Abba Modern
# 2        acts2fellowship       info@acts2fellowship.org     acts2fellowship
# 3              AFX Dance             afxdance@gmail.com           AFX Dance
# 4     Alternative Breaks    berkeleyaltbreaks@gmail.com  Alternative Breaks

# %%
signed_up_clubs_in_callink_percent = len(existing_clubs_df) / len(club_db_df) * 100
print('# of clubs on CalLink:', len(club_json_df))
print('# of clubs on Sproul.club:', len(club_db_df))
print()
print('# of clubs on both platforms:', len(existing_clubs_df))
print('%% of signed up clubs within CalLink: %.1f%%' % signed_up_clubs_in_callink_percent)
# Out:
# # of clubs on CalLink: 1309
# # of clubs on Sproul.club: 199
#
# # of clubs on both platforms: 124
# % of signed up clubs within CalLink: 62.3%

# %% [markdown]
# # Step 1a: Merge data by same email

# %%
existing_clubs_df_by_email = pd.merge(
    club_json_df, club_db_df,
    how='inner', on='email',
    suffixes=('_callink', '_mongo')
)

matching_names = existing_clubs_df_by_email['name_callink'] == existing_clubs_df_by_email['name_mongo']
existing_clubs_df_by_email['match'] = matching_names
existing_clubs_df_by_email
# Out:
#                                           name_callink  \
# 0                                5&2 Community Service
# 1                                          Abba Modern
# 2                                      acts2fellowship
# 3                                            AFX Dance
# 4                                   Alternative Breaks
# 5    American Chemical Society at Berkeley Student ...
# 6    American Medical Student Association--Berkeley...
# 7                                 Artists in Resonance
# 8                         Asha for Education, Berkeley
# 9    Asian American and Pacific Islander Health Res...
# 10          Asian Pacific American Pre-Law Association
# 11   Assistants, Therapists, And Practitioners at B...
# 12       Association for Socially Responsible Business
# 13                            ASUC - Innovative Design
# 14                       ASUC Mental Health Commission
# 15                           ASUC Student Legal Clinic
# 16   ASUC Technology Office- Chief Technology Offic...
# 17                                     Aurum Cosmetics
# 18                Ballet Folklorico Reflejos De Mexico
# 19   Bay Area Environmentally Aware Consulting Network
# 20   Berkeley Art Museum Pacific Film Archive Stude...
# 21                                 Berkeley Forum, The
# 22                                 Berkeley Innovation
# 23                         Berkeley Scientific Journal
# 24   Berkeley Tennis Association (Formerly Tennis a...
# 25    Bhagat Puran Singh Health Initiative at Berkeley
# 26                                Big Data at Berkeley
# 27                                          BioethiCAL
# 28                            Biofuels Technology Club
# 29   Blockchain at Berkeley (formerly Bitcoin Assoc...
# 30                                           Blockeley
# 31                Blueprint, Technology for Nonprofits
# 32                               BridgeUSA at Berkeley
# 33              Business Careers in Entertainment Club
# 34                         Business Review at Berkeley
# 35               Business Transfer Network of Berkeley
# 36                                  Cal Figure Skating
# 37                             Cal Seismic Design Team
# 38   California Health Professional Student Allianc...
# 39                                   Californians, The
# 40                                              CalSol
# 41   CMG Strategy Consulting (Formerly Creative Mar...
# 42                                            Codebase
# 43                                           Codeology
# 44                            Computer Science Mentors
# 45   Crossroads Christian Fellowship: Chinese for C...
# 46                                         Cub Support
# 47                                       Dance the Bay
# 48                                           Danceworx
# 49                    Data Science Society at Berkeley
# 50                                           DataStory
# 51   Delta Phi Epsilon Co-ed Professional Foreign S...
# 52                 Delta Xi Phi Multicultural Sorority
# 53                                  Design at Berkeley
# 54                                         DiversaTech
# 55                                Eggster Organization
# 56                   Engineers and Mentors of Berkeley
# 57                                     EthiCAL Apparel
# 58                                           EXP Dance
# 59                        Extended Reality at Berkeley
# 60       Formula Electric at Berkeley (Formerly bLoop)
# 61       Formula SAE (Society of Automotive Engineers)
# 62   Future Business Leaders of America-Phi Beta La...
# 63             Game Design and Development at Berkeley
# 64                                    Gamma Rho Lambda
# 65            Girls Teaching Girls to Code at Berkeley
# 66                          Girls Who Code at Berkeley
# 67    Global Research and Consulting Group at Berkeley
# 68                                GlobeMed at Berkeley
# 69                    Haas Business School Association
# 70                                        Hack the Bay
# 71                                       Hep B Project
# 72                              Her Campus of Berkeley
# 73                               Human Powered Vehicle
# 74                         Indian Students Association
# 75       Institute of Industrial and Systems Engineers
# 76                         Invention Corps of Berkeley
# 77                                            Jericho!
# 78                                   Kappa Gamma Delta
# 79                                          Kendo Club
# 80      Kidney Disease Screening and Awareness Program
# 81                                           Launchpad
# 82                                 Legends of Berkeley
# 83                  Liberty in North Korea at Berkeley
# 84                               LW Passion Fellowship
# 85                     Medical Reallocation Initiative
# 86                            Microfinance at Berkeley
# 87                       Mobile Developers of Berkeley
# 88   Molecular and Cell Biology Cell Developmental ...
# 89   Molecular Cell Biology Undergraduate Student A...
# 90                               Music Connection, The
# 91                                Nikkei Student Union
# 92               Partners In Health Engage at Berkeley
# 93                                Peer Health Exchange
# 94   Perennial : The Undergraduate Environmental Jo...
# 95                                     Phi Alpha Theta
# 96                                   Phi Delta Epsilon
# 97                                            PlexTech
# 98   Pre-Pharmacy Informational, Learning and Leade...
# 99                                   PreDental Society
# 100                                      Product Space
# 101                Project RISHI, The Berkeley Chapter
# 102                   Queer Alliance & Resource Center
# 103                                        Reinnervate
# 104                 Sales and Trading Club at Berkeley
# 105                                     Sigma Alpha Nu
# 106              SKY Campus Happiness Club at Berkeley
# 107                         Society of Women Engineers
# 108                       Space Enterprise at Berkeley
# 109                    Sri Lankan Students Association
# 110                 Student to Student Peer Counseling
# 111  Support, ENcourage and Develop for Children of...
# 112                      Taiwanese Student Association
# 113                                           Team HBV
# 114   Translational Medicine and Stem Cell Association
# 115               Tzu Chi Compassion Relief Foundation
# 116                   UC Berkeley Model United Nations
# 117                Undergraduate Economics Association
# 118  Undergraduate Legal Honors Society (Formerly L...
# 119                     Vietnamese Student Association
# 120         Volunteer Health Interpreters Organization
# 121                    Volunteers for Medical Outreach
# 122                                 Voyager Consulting
# 123                                      You Mean More
#
#                                        email  \
# 0              fiveandtwo.berkeley@gmail.com
# 1                       abbamodern@gmail.com
# 2                   info@acts2fellowship.org
# 3                         afxdance@gmail.com
# 4                berkeleyaltbreaks@gmail.com
# 5                      acsberkeley@gmail.com
# 6                     berkeleyamsa@gmail.com
# 7            artistsinresonanceucb@gmail.com
# 8                       berkeley@ashanet.org
# 9                     aapihrg.info@gmail.com
# 10                      ucb.apapla@gmail.com
# 11                       atpucberk@gmail.com
# 12                  asrbatberkeley@gmail.com
# 13           innovativedesignatcal@gmail.com
# 14           mentalhealthcommission@asuc.org
# 15                 asuclegalclinic@gmail.com
# 16                       technology@asuc.org
# 17               calaurumcosmetics@gmail.com
# 18            reflejosdemexico.cal@gmail.com
# 19                   info@beacn.berkeley.edu
# 20                     bampfasc@berkeley.edu
# 21                   info@forum.berkeley.edu
# 22             berkeley.innovation@gmail.com
# 23                    bsj.berkeley@gmail.com
# 24       berkeleytennisassociation@gmail.com
# 25                      ucberkeley@bpshi.com
# 26                bigdata.berkeley@gmail.com
# 27             bioethical.berkeley@gmail.com
# 28              biofuelstechnology@gmail.com
# 29             admin@blockchain.berkeley.edu
# 30                        info@blockeley.com
# 31                     team@calblueprint.org
# 32              bridgeusa.berkeley@gmail.com
# 33                         calbcec@gmail.com
# 34        businessreviewatberkeley@gmail.com
# 35             btnexecboard@btn.berkeley.edu
# 36                ucbfigureskating@gmail.com
# 37                  calseismicteam@gmail.com
# 38                 cahpsa.berkeley@gmail.com
# 39                     berkeleyscc@gmail.com
# 40                    calsol-me@berkeley.edu
# 41                     berkeleycmg@gmail.com
# 42             contact@codebase.berkeley.edu
# 43                       info@codeology.club
# 44                      mentors@berkeley.edu
# 45                        xroadscf@gmail.com
# 46                    ucbears4cubs@gmail.com
# 47                     dancethebay@gmail.com
# 48                   dwxpresidents@gmail.com
# 49                     info@dss.berkeley.edu
# 50             datastory.president@gmail.com
# 51                     berkeleydpe@gmail.com
# 52                   ucbdeltaxiphi@gmail.com
# 53                    designatberk@gmail.com
# 54            diversatech.berkeley@gmail.com
# 55                  eggsteroverall@gmail.com
# 56                      beam.teach@gmail.com
# 57                  ethicalapparel@gmail.com
# 58                    expdancecrew@gmail.com
# 59                   contact@xr.berkeley.edu
# 60                   contact@ev.berkeley.edu
# 61                      fsae@me.berkeley.edu
# 62                    execs@pbl.berkeley.edu
# 63                   calgamedev@berkeley.edu
# 64                 lambda@gammarholambda.org
# 65   ucberkeley@girlsteachinggirlstocode.org
# 66                     gwcberkeley@gmail.com
# 67               berkeley@grcglobalgroup.com
# 68                     berkeley@globemed.org
# 69                     hbsageneral@gmail.com
# 70                          team@calhacks.io
# 71                     hepbproject@gmail.com
# 72               hc.ucberkeley@hercampus.com
# 73                       hpv-me@berkeley.edu
# 74                  contact@isa.berkeley.edu
# 75                         iise@berkeley.edu
# 76           inventioncorps@icb.berkeley.edu
# 77                   jerichocomedy@gmail.com
# 78                 ucbkgdpresident@gmail.com
# 79              kendoclub.berkeley@gmail.com
# 80                   berkeleykdsap@gmail.com
# 81                     team@callaunchpad.org
# 82         berkeleyleagueoflegends@gmail.com
# 83                     linkbayarea@gmail.com
# 84              passionlivingwater@gmail.com
# 85                  contact@mri.berkeley.edu
# 86            berkeleymicrofinance@gmail.com
# 87                           contact@mdb.dev
# 88                         mcbcdna@gmail.com
# 89                          mcbusa@gmail.com
# 90                     tmcberkeley@gmail.com
# 91                     berkeleynsu@gmail.com
# 92           pih.engage.ucberkeley@gmail.com
# 93                         ucb.phe@gmail.com
# 94                    calperennial@gmail.com
# 95                   phat.berkeley@gmail.com
# 96                   berkeleyphide@gmail.com
# 97                info@plextech.berkeley.edu
# 98               pills.prepharmacy@gmail.com
# 99             calpredentalsociety@gmail.com
# 100                     cal@productspace.org
# 101              ucberkeley@projectrishi.org
# 102                        board@ucbqarc.org
# 103                    reinnervate@gmail.com
# 104            berkeleyfinanceclub@gmail.com
# 105               sigmaalphanu.cal@gmail.com
# 106           skybreathingberkeley@gmail.com
# 107                   swe.berkeley@gmail.com
# 108                    info@seb.berkeley.edu
# 109                        ucbslsa@gmail.com
# 110                      sspcemail@gmail.com
# 111                    calsendforc@gmail.com
# 112                   tsa.berkeley@gmail.com
# 113                   ucberkeley@teamhbv.org
# 114                  tmscaberkeley@gmail.com
# 115                     berkeleytc@gmail.com
# 116                     secretary@ucbmun.org
# 117                  ucberkeleyuea@gmail.com
# 118                  board@ulhs.berkeley.edu
# 119                     president@calvsa.com
# 120                       cal.vhio@gmail.com
# 121                         calvmo@gmail.com
# 122         info.voyagerconsulting@gmail.com
# 123                    youmeanmore@gmail.com
#
#                                             name_mongo  match
# 0                                         5&2 Berkeley  False
# 1                                          Abba Modern   True
# 2                                      acts2fellowship   True
# 3                                            AFX Dance   True
# 4                                   Alternative Breaks   True
# 5    American Chemical Society at Berkeley (ACS@Ber...  False
# 6                 American Medical Student Association  False
# 7                                 Artists in Resonance   True
# 8                         Asha for Education, Berkeley   True
# 9    Asian American and Pacific Islander Health Res...   True
# 10          Asian Pacific American Pre-Law Association   True
# 11           Assistants, Therapists, and Practitioners  False
# 12   Association for Socially Responsible Business ...  False
# 13                                   Innovative Design  False
# 14                       ASUC Mental Health Commission   True
# 15                           ASUC Student Legal Clinic   True
# 16                              ASUC Office of the CTO  False
# 17                                     Aurum Cosmetics   True
# 18                Ballet Folklorico Reflejos de Mexico  False
# 19                                               BEACN  False
# 20                            BAMPFA Student Committee  False
# 21                                  The Berkeley Forum  False
# 22                                 Berkeley Innovation   True
# 23                         Berkeley Scientific Journal   True
# 24                         Berkeley Tennis Association  False
# 25                                   UC Berkeley BPSHI  False
# 26                                Big Data at Berkeley   True
# 27                                          BioethiCAL   True
# 28                            Biofuels Technology Club   True
# 29                              Blockchain at Berkeley  False
# 30                                           Blockeley   True
# 31                Blueprint, Technology for Nonprofits   True
# 32                                           BridgeUSA  False
# 33       Business Careers in Entertainment Club (BCEC)  False
# 34                         Business Review at Berkeley   True
# 35                           Business Transfer Network  False
# 36                                  Cal Figure Skating   True
# 37                             Cal Seismic Design Team   True
# 38     California Health Professional Student Alliance  False
# 39                                Senior Class Council  False
# 40                                              CalSol   True
# 41                             CMG Strategy Consulting  False
# 42                                            Codebase   True
# 43                                           Codeology   True
# 44                      Computer Science Mentors (CSM)  False
# 45                     Crossroads Christian Fellowship  False
# 46                                         Cub Support   True
# 47                                       Dance the Bay   True
# 48                                           Danceworx   True
# 49                     Data Science Society @ Berkeley  False
# 50                                           DataStory   True
# 51   Delta Phi Epsilon: Professional Co-Ed Foreign ...  False
# 52                 Delta Xi Phi Multicultural Sorority   True
# 53                                  Design at Berkeley   True
# 54                                         DiversaTech   True
# 55                                Eggster Organization   True
# 56                Berkeley Engineers and Mentors--BEAM  False
# 57                                     Ethical Apparel  False
# 58                                           EXP Dance   True
# 59                        Extended Reality at Berkeley   True
# 60                        Formula Electric at Berkeley  False
# 61                             Berkeley Formula Racing  False
# 62                            Berkeley Phi Beta Lambda  False
# 63              Game Design and Development @ Berkeley  False
# 64                                    Gamma Rho Lambda   True
# 65                        Girls Teaching Girls to Code  False
# 66                          Girls Who Code at Berkeley   True
# 67    Global Research and Consulting Group at Berkeley   True
# 68                                GlobeMed at Berkeley   True
# 69             Haas Business School Association (HBSA)  False
# 70                                           Cal Hacks  False
# 71                                       Hep B Project   True
# 72                              Her Campus at Berkeley  False
# 73                          Human Powered Vehicle Team  False
# 74                         Indian Students Association   True
# 75   Institute of Industrial and Systems Engineers ...  False
# 76                            Invention Corps Berkeley  False
# 77                   jericho! improv and sketch comedy  False
# 78                                   Kappa Gamma Delta   True
# 79                              Kendo Club at Berkeley  False
# 80   Kidney Disease Screening and Awareness Program...  False
# 81                                           Launchpad   True
# 82                                    Berkeley Legends  False
# 83           Liberty in North Korea (LiNK) at Berkeley  False
# 84                               LW Passion Fellowship   True
# 85                     Medical Reallocation Initiative   True
# 86                            Microfinance at Berkeley   True
# 87                       Mobile Developers of Berkeley   True
# 88   Molecular & Cell Biology, Cell Developmental, ...  False
# 89                                              mcbUSA  False
# 90                                The Music Connection  False
# 91                                Nikkei Student Union   True
# 92                           Partners in Health Engage  False
# 93                                Peer Health Exchange   True
# 94   Perennial: The Undergraduate Environmental Jou...  False
# 95                                     Phi Alpha Theta   True
# 96                                   Phi Delta Epsilon   True
# 97                                            PlexTech   True
# 98   Pre-Pharmacy Informational, Learning and Leade...   True
# 99                         Berkeley Pre-Dental Society  False
# 100                       Product Space at UC Berkeley  False
# 101                                      Project RISHI  False
# 102                     Queer Alliance Resource Center  False
# 103                                        Reinnervate   True
# 104                              Berkeley Finance Club  False
# 105                                     Sigma Alpha Nu   True
# 106              SKY Campus Happiness Club at Berkeley   True
# 107                         Society of Women Engineers   True
# 108                       Space Enterprise at Berkeley   True
# 109                    Sri Lankan Students Association   True
# 110                 Student to Student Peer Counseling   True
# 111  SENDforC (Support, ENcourage, and Develop for ...  False
# 112                      Taiwanese Student Association   True
# 113                                           Team HBV   True
# 114   Translational Medicine and Stem Cell Association   True
# 115               Tzu Chi Compassion Relief Foundation   True
# 116                   UC Berkeley Model United Nations   True
# 117                Undergraduate Economics Association   True
# 118                  Undergraduate Legal Honor Society  False
# 119                 Cal Vietnamese Student Association  False
# 120         Volunteer Health Interpreters Organization   True
# 121              Volunteers for Medical Outreach (VMO)  False
# 122                                 Voyager Consulting   True
# 123                                      You Mean More   True

# %%
print('# of matching names:', sum(matching_names))
print('# of non-matching names:', len(matching_names) - sum(matching_names))
print('%% of matching names: %.1f%%' % ( sum(matching_names) / len(matching_names) * 100 ))
# Out:
# # of matching names: 68
# # of non-matching names: 56
# % of matching names: 54.8%

# %% [markdown]
# # Step 1b: Merge data by same name

# %%
existing_clubs_df_by_name = pd.merge(
    club_json_df, club_db_df,
    how='inner', on='name',
    suffixes=('_callink', '_mongo')
)

matching_emails = existing_clubs_df_by_name['email_callink'] == existing_clubs_df_by_name['email_mongo']
existing_clubs_df_by_name['match'] = matching_emails
existing_clubs_df_by_name
# Out:
#                                                  name  \
# 0               3D Modeling and Animation at Berkeley
# 1                                         Abba Modern
# 2                                     acts2fellowship
# 3                                           AFX Dance
# 4                                     Alpha Kappa Psi
# 5                                  Alternative Breaks
# 6                                Artists in Resonance
# 7                        Asha for Education, Berkeley
# 8   Asian American and Pacific Islander Health Res...
# 9          Asian Pacific American Pre-Law Association
# 10                      ASUC Mental Health Commission
# 11                    ASUC Sexual Violence Commission
# 12                          ASUC Student Legal Clinic
# 13                                    Aurum Cosmetics
# 14                          Berkeley Business Society
# 15                           Berkeley Economic Review
# 16                                Berkeley Innovation
# 17                        Berkeley Scientific Journal
# 18                               Big Data at Berkeley
# 19                                         BioethiCAL
# 20                           Biofuels Technology Club
# 21                                          Blockeley
# 22               Blueprint, Technology for Nonprofits
# 23                             Bone Health Initiative
# 24                        Business Review at Berkeley
# 25                                 Cal Figure Skating
# 26                           Cal Habitat for Humanity
# 27                                       Cal Rotaract
# 28                            Cal Seismic Design Team
# 29                              Cal Table Tennis Club
# 30                                             CalSol
# 31                                           Codebase
# 32                                          Codeology
# 33                                        Cub Support
# 34                                      Dance the Bay
# 35                                          Danceworx
# 36                   Data Science Society at Berkeley
# 37                                          DataStory
# 38                Delta Xi Phi Multicultural Sorority
# 39                                 Design at Berkeley
# 40                                        DiversaTech
# 41                               Eggster Organization
# 42                        Engineering Student Council
# 43                 Equity Beyond Barriers at Berkeley
# 44                                       Eta Kappa Nu
# 45                                          EXP Dance
# 46                       Extended Reality at Berkeley
# 47                       Fiat Lux Institute of Policy
# 48                                      Free Ventures
# 49                                   Gamma Rho Lambda
# 50                         Girls Who Code at Berkeley
# 51   Global Research and Consulting Group at Berkeley
# 52                               GlobeMed at Berkeley
# 53                                      Hep B Project
# 54                                 Humans of Berkeley
# 55                        Indian Students Association
# 56                                  Kappa Gamma Delta
# 57                                  Kappa Gamma Delta
# 58                                          Launchpad
# 59                              LW Passion Fellowship
# 60                                        Matriculate
# 61                    Medical Reallocation Initiative
# 62                    Medical Reallocation Initiative
# 63                           Microfinance at Berkeley
# 64                      Mobile Developers of Berkeley
# 65                               Nikkei Student Union
# 66                               Peer Health Exchange
# 67                  People's Test Preparation Service
# 68                                    Phi Alpha Theta
# 69                                  Phi Delta Epsilon
# 70                                      Phi Sigma Rho
# 71                           Phoenix Consulting Group
# 72                                   Pi Sigma Epsilon
# 73                                           PlexTech
# 74  Pre-Pharmacy Informational, Learning and Leade...
# 75                             Public Health Advocate
# 76                                        Reinnervate
# 77                                     Sigma Alpha Nu
# 78                                Sigma Epsilon Omega
# 79              SKY Campus Happiness Club at Berkeley
# 80                         Society of Women Engineers
# 81                       Space Enterprise at Berkeley
# 82                    Sri Lankan Students Association
# 83         Student Association for Applied Statistics
# 84                 Student to Student Peer Counseling
# 85                                    Suitcase Clinic
# 86                      Taiwanese Student Association
# 87                                           Team HBV
# 88   Translational Medicine and Stem Cell Association
# 89               Tzu Chi Compassion Relief Foundation
# 90                   UC Berkeley Model United Nations
# 91                Undergraduate Economics Association
# 92                                           UrsaTech
# 93                            Valley Consulting Group
# 94         Volunteer Health Interpreters Organization
# 95                                 Voyager Consulting
# 96                                      You Mean More
#
#                            email_callink  \
# 0             3dma.at.berkeley@gmail.com
# 1                   abbamodern@gmail.com
# 2               info@acts2fellowship.org
# 3                     afxdance@gmail.com
# 4               sanampatel1999@gmail.com
# 5            berkeleyaltbreaks@gmail.com
# 6        artistsinresonanceucb@gmail.com
# 7                   berkeley@ashanet.org
# 8                 aapihrg.info@gmail.com
# 9                   ucb.apapla@gmail.com
# 10       mentalhealthcommission@asuc.org
# 11               sexualviolence@asuc.org
# 12             asuclegalclinic@gmail.com
# 13           calaurumcosmetics@gmail.com
# 14     BerkeleyBusinessSociety@gmail.com
# 15        editor@econreview.berkeley.edu
# 16         berkeley.innovation@gmail.com
# 17                bsj.berkeley@gmail.com
# 18            bigdata.berkeley@gmail.com
# 19         bioethical.berkeley@gmail.com
# 20          biofuelstechnology@gmail.com
# 21                    info@blockeley.com
# 22                 team@calblueprint.org
# 23                 info@bhi.berkeley.edu
# 24    businessreviewatberkeley@gmail.com
# 25            ucbfigureskating@gmail.com
# 26             calhabitat.pres@gmail.com
# 27                  info@calrotaract.org
# 28              calseismicteam@gmail.com
# 29                                  None
# 30                calsol-me@berkeley.edu
# 31         contact@codebase.berkeley.edu
# 32                   info@codeology.club
# 33                ucbears4cubs@gmail.com
# 34                 dancethebay@gmail.com
# 35               dwxpresidents@gmail.com
# 36                 info@dss.berkeley.edu
# 37         datastory.president@gmail.com
# 38               ucbdeltaxiphi@gmail.com
# 39                designatberk@gmail.com
# 40        diversatech.berkeley@gmail.com
# 41              eggsteroverall@gmail.com
# 42            president@esc.berkeley.edu
# 43        equitybeyondbarriers@gmail.com
# 44             hkn@hkn.eecs.berkeley.edu
# 45                expdancecrew@gmail.com
# 46               contact@xr.berkeley.edu
# 47                a.mendoza@berkeley.edu
# 48            pranav.gulati@berkeley.edu
# 49             lambda@gammarholambda.org
# 50                 gwcberkeley@gmail.com
# 51           berkeley@grcglobalgroup.com
# 52                 berkeley@globemed.org
# 53                 hepbproject@gmail.com
# 54                  anyal23@berkeley.edu
# 55              contact@isa.berkeley.edu
# 56             ucbkgdpresident@gmail.com
# 57             ucbkgdpresident@gmail.com
# 58                 team@callaunchpad.org
# 59          passionlivingwater@gmail.com
# 60                  info@matriculate.org
# 61              contact@mri.berkeley.edu
# 62              contact@mri.berkeley.edu
# 63        berkeleymicrofinance@gmail.com
# 64                       contact@mdb.dev
# 65                 berkeleynsu@gmail.com
# 66                     ucb.phe@gmail.com
# 67               ptps.berkeley@gmail.com
# 68               phat.berkeley@gmail.com
# 69               berkeleyphide@gmail.com
# 70                   calphirho@gmail.com
# 71  phoenixconsulting.berkeley@gmail.com
# 72       berkeleypse.president@gmail.com
# 73            info@plextech.berkeley.edu
# 74           pills.prepharmacy@gmail.com
# 75       editorialboard@pha.berkeley.edu
# 76                 reinnervate@gmail.com
# 77            sigmaalphanu.cal@gmail.com
# 78            info@sigmaepsilonomega.com
# 79        skybreathingberkeley@gmail.com
# 80                swe.berkeley@gmail.com
# 81                 info@seb.berkeley.edu
# 82                     ucbslsa@gmail.com
# 83             contact@saas.berkeley.edu
# 84                   sspcemail@gmail.com
# 85          suitcaseclinic1989@gmail.com
# 86                tsa.berkeley@gmail.com
# 87                ucberkeley@teamhbv.org
# 88               tmscaberkeley@gmail.com
# 89                  berkeleytc@gmail.com
# 90                  secretary@ucbmun.org
# 91               ucberkeleyuea@gmail.com
# 92                                  None
# 93                 info@vcg.berkeley.edu
# 94                    cal.vhio@gmail.com
# 95      info.voyagerconsulting@gmail.com
# 96                 youmeanmore@gmail.com
#
#                                  email_mongo  match
# 0                           staff@ucbugg.com  False
# 1                       abbamodern@gmail.com   True
# 2                   info@acts2fellowship.org   True
# 3                         afxdance@gmail.com   True
# 4            corporaterelations@calakpsi.com  False
# 5                berkeleyaltbreaks@gmail.com   True
# 6            artistsinresonanceucb@gmail.com   True
# 7                       berkeley@ashanet.org   True
# 8                     aapihrg.info@gmail.com   True
# 9                       ucb.apapla@gmail.com   True
# 10           mentalhealthcommission@asuc.org   True
# 11         sexualviolencecommission@asuc.org  False
# 12                 asuclegalclinic@gmail.com   True
# 13               calaurumcosmetics@gmail.com   True
# 14                         bbs.ucb@gmail.com  False
# 15              berkeleyeconreview@gmail.com  False
# 16             berkeley.innovation@gmail.com   True
# 17                    bsj.berkeley@gmail.com   True
# 18                bigdata.berkeley@gmail.com   True
# 19             bioethical.berkeley@gmail.com   True
# 20              biofuelstechnology@gmail.com   True
# 21                        info@blockeley.com   True
# 22                     team@calblueprint.org   True
# 23                          bhi@berkeley.edu  False
# 24        businessreviewatberkeley@gmail.com   True
# 25                ucbfigureskating@gmail.com   True
# 26        calhabitat.vicepresident@gmail.com  False
# 27                 executive@calrotaract.org  False
# 28                  calseismicteam@gmail.com   True
# 29                          calttc@gmail.com  False
# 30                    calsol-me@berkeley.edu   True
# 31             contact@codebase.berkeley.edu   True
# 32                       info@codeology.club   True
# 33                    ucbears4cubs@gmail.com   True
# 34                     dancethebay@gmail.com   True
# 35                   dwxpresidents@gmail.com   True
# 36                    dss.berkeley@gmail.com  False
# 37             datastory.president@gmail.com   True
# 38                   ucbdeltaxiphi@gmail.com   True
# 39                    designatberk@gmail.com   True
# 40            diversatech.berkeley@gmail.com   True
# 41                  eggsteroverall@gmail.com   True
# 42                       esc.comms@gmail.com  False
# 43  equitybeyondbarriersatberkeley@gmail.com  False
# 44                                hkn@hkn.mu  False
# 45                    expdancecrew@gmail.com   True
# 46                   contact@xr.berkeley.edu   True
# 47                  dhavalpatel@berkeley.edu  False
# 48                   nikita@freeventures.org  False
# 49                 lambda@gammarholambda.org   True
# 50                     gwcberkeley@gmail.com   True
# 51               berkeley@grcglobalgroup.com   True
# 52                     berkeley@globemed.org   True
# 53                     hepbproject@gmail.com   True
# 54                humansofberkeley@gmail.com  False
# 55                  contact@isa.berkeley.edu   True
# 56                 ucbkgdpresident@gmail.com   True
# 57           ucbkgdpublicrelations@gmail.com  False
# 58                     team@callaunchpad.org   True
# 59              passionlivingwater@gmail.com   True
# 60                  ucbmatriculate@gmail.com  False
# 61                        teambmri@gmail.com  False
# 62                  contact@mri.berkeley.edu   True
# 63            berkeleymicrofinance@gmail.com   True
# 64                           contact@mdb.dev   True
# 65                     berkeleynsu@gmail.com   True
# 66                         ucb.phe@gmail.com   True
# 67               publicity@ptps.berkeley.edu  False
# 68                   phat.berkeley@gmail.com   True
# 69                   berkeleyphide@gmail.com   True
# 70              recruitment.calpsr@gmail.com  False
# 71                       nian_s@berkeley.edu  False
# 72                  berkeleypse.hr@gmail.com  False
# 73                info@plextech.berkeley.edu   True
# 74               pills.prepharmacy@gmail.com   True
# 75            publichealthadvocate@gmail.com  False
# 76                     reinnervate@gmail.com   True
# 77                sigmaalphanu.cal@gmail.com   True
# 78           president@sigmaepsilonomega.com  False
# 79            skybreathingberkeley@gmail.com   True
# 80                    swe.berkeley@gmail.com   True
# 81                     info@seb.berkeley.edu   True
# 82                         ucbslsa@gmail.com   True
# 83                   saas.berkeley@gmail.com  False
# 84                       sspcemail@gmail.com   True
# 85                      suitcasepr@gmail.com  False
# 86                    tsa.berkeley@gmail.com   True
# 87                    ucberkeley@teamhbv.org   True
# 88                   tmscaberkeley@gmail.com   True
# 89                      berkeleytc@gmail.com   True
# 90                      secretary@ucbmun.org   True
# 91                   ucberkeleyuea@gmail.com   True
# 92                ursatechberkeley@gmail.com  False
# 93                      evp@vcg.berkeley.edu  False
# 94                        cal.vhio@gmail.com   True
# 95          info.voyagerconsulting@gmail.com   True
# 96                     youmeanmore@gmail.com   True

# %%
print('# of matching emails:', sum(matching_emails))
print('# of non-matching emails:', len(matching_emails) - sum(matching_emails))
print('%% of matching emails: %.1f%%' % ( sum(matching_emails) / len(matching_emails) * 100 ))
# Out:
# # of matching emails: 68
# # of non-matching emails: 29
# % of matching emails: 70.1%

# %% [markdown]
# # Step 1c: Merge data by same email and name

# %%
existing_clubs_df_by_email_name = pd.merge(
    club_json_df, club_db_df,
    how='inner',
    suffixes=('_callink', '_mongo')
)

existing_clubs_df_by_email_name
# Out:
#                                                  name  \
# 0                                         Abba Modern
# 1                                     acts2fellowship
# 2                                           AFX Dance
# 3                                  Alternative Breaks
# 4                                Artists in Resonance
# 5                        Asha for Education, Berkeley
# 6   Asian American and Pacific Islander Health Res...
# 7          Asian Pacific American Pre-Law Association
# 8                       ASUC Mental Health Commission
# 9                           ASUC Student Legal Clinic
# 10                                    Aurum Cosmetics
# 11                                Berkeley Innovation
# 12                        Berkeley Scientific Journal
# 13                               Big Data at Berkeley
# 14                                         BioethiCAL
# 15                           Biofuels Technology Club
# 16                                          Blockeley
# 17               Blueprint, Technology for Nonprofits
# 18                        Business Review at Berkeley
# 19                                 Cal Figure Skating
# 20                            Cal Seismic Design Team
# 21                                             CalSol
# 22                                           Codebase
# 23                                          Codeology
# 24                                        Cub Support
# 25                                      Dance the Bay
# 26                                          Danceworx
# 27                                          DataStory
# 28                Delta Xi Phi Multicultural Sorority
# 29                                 Design at Berkeley
# 30                                        DiversaTech
# 31                               Eggster Organization
# 32                                          EXP Dance
# 33                       Extended Reality at Berkeley
# 34                                   Gamma Rho Lambda
# 35                         Girls Who Code at Berkeley
# 36   Global Research and Consulting Group at Berkeley
# 37                               GlobeMed at Berkeley
# 38                                      Hep B Project
# 39                        Indian Students Association
# 40                                  Kappa Gamma Delta
# 41                                          Launchpad
# 42                              LW Passion Fellowship
# 43                    Medical Reallocation Initiative
# 44                           Microfinance at Berkeley
# 45                      Mobile Developers of Berkeley
# 46                               Nikkei Student Union
# 47                               Peer Health Exchange
# 48                                    Phi Alpha Theta
# 49                                  Phi Delta Epsilon
# 50                                           PlexTech
# 51  Pre-Pharmacy Informational, Learning and Leade...
# 52                                        Reinnervate
# 53                                     Sigma Alpha Nu
# 54              SKY Campus Happiness Club at Berkeley
# 55                         Society of Women Engineers
# 56                       Space Enterprise at Berkeley
# 57                    Sri Lankan Students Association
# 58                 Student to Student Peer Counseling
# 59                      Taiwanese Student Association
# 60                                           Team HBV
# 61   Translational Medicine and Stem Cell Association
# 62               Tzu Chi Compassion Relief Foundation
# 63                   UC Berkeley Model United Nations
# 64                Undergraduate Economics Association
# 65         Volunteer Health Interpreters Organization
# 66                                 Voyager Consulting
# 67                                      You Mean More
#
#                                  email
# 0                 abbamodern@gmail.com
# 1             info@acts2fellowship.org
# 2                   afxdance@gmail.com
# 3          berkeleyaltbreaks@gmail.com
# 4      artistsinresonanceucb@gmail.com
# 5                 berkeley@ashanet.org
# 6               aapihrg.info@gmail.com
# 7                 ucb.apapla@gmail.com
# 8      mentalhealthcommission@asuc.org
# 9            asuclegalclinic@gmail.com
# 10         calaurumcosmetics@gmail.com
# 11       berkeley.innovation@gmail.com
# 12              bsj.berkeley@gmail.com
# 13          bigdata.berkeley@gmail.com
# 14       bioethical.berkeley@gmail.com
# 15        biofuelstechnology@gmail.com
# 16                  info@blockeley.com
# 17               team@calblueprint.org
# 18  businessreviewatberkeley@gmail.com
# 19          ucbfigureskating@gmail.com
# 20            calseismicteam@gmail.com
# 21              calsol-me@berkeley.edu
# 22       contact@codebase.berkeley.edu
# 23                 info@codeology.club
# 24              ucbears4cubs@gmail.com
# 25               dancethebay@gmail.com
# 26             dwxpresidents@gmail.com
# 27       datastory.president@gmail.com
# 28             ucbdeltaxiphi@gmail.com
# 29              designatberk@gmail.com
# 30      diversatech.berkeley@gmail.com
# 31            eggsteroverall@gmail.com
# 32              expdancecrew@gmail.com
# 33             contact@xr.berkeley.edu
# 34           lambda@gammarholambda.org
# 35               gwcberkeley@gmail.com
# 36         berkeley@grcglobalgroup.com
# 37               berkeley@globemed.org
# 38               hepbproject@gmail.com
# 39            contact@isa.berkeley.edu
# 40           ucbkgdpresident@gmail.com
# 41               team@callaunchpad.org
# 42        passionlivingwater@gmail.com
# 43            contact@mri.berkeley.edu
# 44      berkeleymicrofinance@gmail.com
# 45                     contact@mdb.dev
# 46               berkeleynsu@gmail.com
# 47                   ucb.phe@gmail.com
# 48             phat.berkeley@gmail.com
# 49             berkeleyphide@gmail.com
# 50          info@plextech.berkeley.edu
# 51         pills.prepharmacy@gmail.com
# 52               reinnervate@gmail.com
# 53          sigmaalphanu.cal@gmail.com
# 54      skybreathingberkeley@gmail.com
# 55              swe.berkeley@gmail.com
# 56               info@seb.berkeley.edu
# 57                   ucbslsa@gmail.com
# 58                 sspcemail@gmail.com
# 59              tsa.berkeley@gmail.com
# 60              ucberkeley@teamhbv.org
# 61             tmscaberkeley@gmail.com
# 62                berkeleytc@gmail.com
# 63                secretary@ucbmun.org
# 64             ucberkeleyuea@gmail.com
# 65                  cal.vhio@gmail.com
# 66    info.voyagerconsulting@gmail.com
# 67               youmeanmore@gmail.com

# %%
print('# of clubs matching by name and email:', len(existing_clubs_df_by_email_name))
# Out:
# # of clubs matching by name and email: 68
